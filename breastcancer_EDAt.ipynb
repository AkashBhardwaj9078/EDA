# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from sklearn import datasets 
dir(datasets)

s=datasets.load_breast_cancer()

# %%
df=pd.DataFrame(s.data,columns=s.feature_names)
df["target"]=s.target
df["target"]=df["target"].map({0:s.target_names[0],1:s.target_names[1]})

# %%
sns.scatterplot(x=df["mean radius"],y=df["mean area"],hue=df["target"])
# Out:
# <AxesSubplot: xlabel='mean radius', ylabel='mean area'>

# %%
sns.scatterplot(x=df["mean radius"],y=df["mean perimeter"],hue=df["target"])
# Out:
# <AxesSubplot: xlabel='mean radius', ylabel='mean perimeter'>

# %%
sns.jointplot(x=df["mean concave points"],y=df["mean concavity"],kind="reg")

# %%
sns.barplot(y=df["worst symmetry"],x=df["target"],palette=["red","pink"],)
# Out:
# <AxesSubplot: xlabel='target', ylabel='worst symmetry'>

# %%
sns.barplot(y=df["mean symmetry"],x=df["target"],palette=["orange","yellow"])
# Out:
# <AxesSubplot: xlabel='target', ylabel='mean symmetry'>

# %%
sns.jointplot(x=df["worst concave points"],y=df["worst concavity"],kind="hex")

# %%
sns.swarmplot(x=df["target"],y=df["mean texture"])
sns.swarmplot(x=df["target"],y=df["worst texture"])

plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x=df["target"],y=df["mean texture"])
sns.violinplot(x=df["target"],y=df["worst texture"])
# Out:
# <AxesSubplot: xlabel='target', ylabel='worst texture'>

# %%
sns.relplot(x=df["worst concavity"],y=df["mean concavity"],hue=df["target"])

# %%
sns.jointplot(x=df["mean area"],y=df["worst area"],hue=df["target"],s=200)

# %%
sns.jointplot(x=df["mean radius"],y=df["worst radius"],hue=df["target"],s=200)

# %%
sns.violinplot(x=df["target"],y=df["mean texture"],hue=df["target"])
sns.swarmplot(x=df["target"],y=df["mean texture"],hue=df["target"])
# Out:
# <AxesSubplot: xlabel='target', ylabel='mean texture'>

# %%
sns.distplot(x=df["area error"],label="area_error")
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\4163224810.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["area error"],label="area_error")
# <AxesSubplot: ylabel='Density'>

# %%
sns.distplot(x=df["perimeter error"],label="perimeter_error")
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\2660413156.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["perimeter error"],label="perimeter_error")
# <AxesSubplot: ylabel='Density'>

# %%
sns.distplot(x=df["radius error"],label="radius_error")
sns.distplot(x=df["texture error"],label="texture_error")

plt.legend()
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\981435053.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["radius error"],label="radius_error")
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\981435053.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...

# %%
sns.histplot(x=df["worst symmetry"],y=df["worst fractal dimension"],hue=df["target"])
# Out:
# <AxesSubplot: xlabel='worst symmetry', ylabel='worst fractal dimension'>

# %%
sns.histplot(x=df["mean fractal dimension"],y=df["worst fractal dimension"],hue=df["target"],element="polly")
# Out:
# <AxesSubplot: xlabel='mean fractal dimension', ylabel='worst fractal dimension'>

# %%
sns.relplot(x=df["worst texture"],y=df["mean texture"],hue=df["target"])

# %%
sns.jointplot(x=df["concavity error"],y=df["concave points error"],kind="kde",color="purple").joint_plot(sns.)
sns.scatterplot(x=df["concavity error"],y=df["concave points error"],hue=df["target"],palette=["red","pink"])
# Out:
# <AxesSubplot: xlabel='concavity error', ylabel='concave points error'>

# %%
sns.boxplot(y=df["perimeter error"],x=df["target"],palette=["red","pink"])
sns.stripplot(y=df["perimeter error"],x=df["target"],palette=["red", "pink"])
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\3740747434.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(y=df["perimeter error"],x=df["target"],palette=["red", "pink"])
# <AxesSubplot: xlabel='target', ylabel='perimeter error'>

# %%
sns.swarmplot(y=df["mean concave points"],x=df["target"],palette=["pink","red"])
sns.violinplot(y=df["mean concave points"],x=df["target"],palette=["pink","red"])
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\3792792353.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(y=df["mean concave points"],x=df["target"],palette=["pink","red"])
# <AxesSubplot: xlabel='target', ylabel='mean concave points'>
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 24.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(y=df["worst compactness"],x=df["target"],palette=["pink","red"])
sns.boxplot(y=df["worst compactness"],x=df["target"],palette=["pink","red"])
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\3114257061.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(y=df["worst compactness"],x=df["target"],palette=["pink","red"])
# <AxesSubplot: xlabel='target', ylabel='worst compactness'>

# %%
sns.swarmplot(y=df['mean fractal dimension'],x=df["target"],palette=["pink","red"])
sns.violinplot(y=df['mean fractal dimension'],x=df["target"],palette=["pink","red"])
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\671760478.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(y=df['mean fractal dimension'],x=df["target"],palette=["pink","red"])
# <AxesSubplot: xlabel='target', ylabel='mean fractal dimension'>
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 7.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.regplot(x=df['worst compactness'],y=df["mean compactness"],color="yellow")
# Out:
# <AxesSubplot: xlabel='worst compactness', ylabel='mean compactness'>

# %%
sns.regplot(x=df["mean texture"],y=df["worst texture"],color="pink")
# Out:
# <AxesSubplot: xlabel='mean texture', ylabel='worst texture'>

# %%
sns.regplot(x=df['worst symmetry'],y=df["mean symmetry"],color="red")
# Out:
# <AxesSubplot: xlabel='worst symmetry', ylabel='mean symmetry'>

# %%
sns.kdeplot(y=df["mean fractal dimension"],x=df["fractal dimension error"],color="yellow",multiple="stack")
sns.kdeplot(y=df["worst fractal dimension"],x=df["fractal dimension error"],color="red",multiple="stack")
sns.scatterplot(y=df["mean fractal dimension"],x=df["fractal dimension error"],color="yellow",marker="^",s=200)
sns.scatterplot(y=df["worst fractal dimension"],x=df["fractal dimension error"],color="red",marker="D",s=200)
# Out:
# <AxesSubplot: xlabel='fractal dimension error', ylabel='mean fractal dimension'>

# %%
sns.scatterplot(y=df["worst area"],x=df["area error"],marker="D",color="red",s=200)
sns.scatterplot(y=df["mean area"],x=df["area error"],color="purple",marker="H",s=200)
plt.
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.regplot(y=df["worst radius"],x=df["radius error"],color="Red",marker="D")
sns.regplot(y=df["mean radius"],x=df["radius error"],color="Pink",marker="H")
# Out:
# <AxesSubplot: xlabel='radius error', ylabel='mean radius'>

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
sns.histplot(y=df["mean smoothness"],x=df["smoothness error"],hue=df["target"],palette=["red","pink"])
sns.histplot(y=df["worst smoothness"],x=df["smoothness error"],hue=df["target"],palette=["red","pink"])
# Out:
# <AxesSubplot: xlabel='smoothness error', ylabel='mean smoothness'>

# %%
sns.regplot(x=df["mean radius"],y=df["mean area"],color="purple",marker="D",)
sns.regplot(x=df["worst radius"],y=df["worst area"],color="red",marker="H")
# Out:
# <AxesSubplot: xlabel='worst radius', ylabel='worst area'>

# %%
sns.violinplot(y=df["worst perimeter"],x=df["target"],palette=["red","yellow"])
sns.violinplot(y=df["mean perimeter"],x=df["target"],palette=["red","yellow"])
sns.swarmplot(y=df["worst perimeter"],x=df["target"],palette=["red","yellow"])
sns.swarmplot(y=df["mean perimeter"],x=df["target"],palette=["red","yellow"])
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\2817035660.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(y=df["worst perimeter"],x=df["target"],palette=["red","yellow"])
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\2817035660.py:4: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(y=df["mean perimeter"],x=df["target"],palette=["red","yellow"])
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 18.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.jointplot(x=df["mean smoothness"],y=df["worst smoothness"],kind="hex",color="purple").plot_joint(sns.kdeplot,color="red")

# %%
sns.jointplot(x=df["mean concavity"],y=df["mean concave points"],kind="hist",color="purple").plot_joint(sns.kdeplot,color="red")

# %%
sns.jointplot(x=df["worst concavity"],y=df["worst concave points"],kind="kde",color="purple").plot_joint(sns.histplot,color="red")

# %%
sns.distplot(x=df["mean compactness"],kde=True,rug=True)
sns.distplot(x=df["worst compactness"],kde=True,rug=True)
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\2101360863.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["mean compactness"],kde=True,rug=True)
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_14396\2101360863.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'target'],
#       dtype='object')

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...
