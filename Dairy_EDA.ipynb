# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.scatterplot(x=df["Total Land Area (acres)"],y=df["Price per Unit"],hue=df["Farm Size"])
# Out:
# <AxesSubplot: xlabel='Total Land Area (acres)', ylabel='Price per Unit'>

# %%
sns.swarmplot(x=df["Brand"],y=df["Quantity (liters/kg)"],hue=df["Farm Size"])

plt.xticks(rotation=90)
# Out:
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 20.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 76.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 76.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.barplot(x=df["Product Name"],y=df["Quantity (liters/kg)"],hue=df["Farm Size"])
# Out:
# <AxesSubplot: xlabel='Product Name', ylabel='Quantity (liters/kg)'>

# %%
sns.lineplot(y=df["Total Land Area (acres)"],x=df["Number of Cows"],hue=df["Brand"])
# Out:
# <AxesSubplot: xlabel='Number of Cows', ylabel='Total Land Area (acres)'>

# %%
df.pivot_table(index="Product Name",columns="Brand",aggfunc=sum,values="Total Land Area (acres)")
# Out:
# Brand             Amul  Britannia Industries  Dodla Dairy  Dynamix Dairies  \
# Product Name
# Butter        50947.10                   NaN          NaN              NaN
# Buttermilk    43975.85                   NaN          NaN              NaN
# Cheese        54186.52              51221.94          NaN         55356.87
# Curd          57700.50                   NaN          NaN              NaN
# Ghee          50299.85                   NaN          NaN              NaN
# Ice Cream     54247.07                   NaN     52341.96              NaN
# Lassi         59475.59                   NaN          NaN              NaN
# Milk          50538.44                   NaN          NaN              NaN
# Paneer        47325.35                   NaN          NaN              NaN
# Yogurt        59681.19                   NaN     59632.69              NaN
#
# Brand         Mother Dairy  Palle2patnam  Parag Milk Foods  Passion Cheese  \
# Product Name
# ...

# %%
df.pivot_table(index="Product Name",columns="Brand",aggfunc=sum,values="Number of Cows")
# Out:
# Brand           Amul  Britannia Industries  Dodla Dairy  Dynamix Dairies  \
# Product Name
# Butter        5832.0                   NaN          NaN              NaN
# Buttermilk    4954.0                   NaN          NaN              NaN
# Cheese        6294.0                4968.0          NaN           5637.0
# Curd          6446.0                   NaN          NaN              NaN
# Ghee          5535.0                   NaN          NaN              NaN
# Ice Cream     5710.0                   NaN       5742.0              NaN
# Lassi         6128.0                   NaN          NaN              NaN
# Milk          5342.0                   NaN          NaN              NaN
# Paneer        5069.0                   NaN          NaN              NaN
# Yogurt        5563.0                   NaN       6612.0              NaN
#
# Brand         Mother Dairy  Palle2patnam  Parag Milk Foods  Passion Cheese  \
# Product Name
# ...

# %%
sns.lineplot(x=df["Price per Unit"],y=df["Price per Unit (sold)"],hue=df["Product Name"])
# Out:
# <AxesSubplot: xlabel='Price per Unit', ylabel='Price per Unit (sold)'>

# %%
sns.barplot(x=df["Storage Condition"],y=df["Shelf Life (days)"])
# Out:
# <AxesSubplot: xlabel='Storage Condition', ylabel='Shelf Life (days)'>

# %%
df.pivot_table(index="Storage Condition",values="Shelf Life (days)",columns="Product Name",aggfunc='sum')
# Out:
# Product Name       Butter  Buttermilk   Cheese    Curd     Ghee  Ice Cream  \
# Storage Condition
# Ambient               NaN         NaN      NaN     NaN  42508.0        NaN
# Frozen             7449.0         NaN  10204.0     NaN      NaN    10769.0
# Polythene Packet      NaN         NaN      NaN     NaN      NaN        NaN
# Refrigerated       6745.0      4599.0  12783.0  2886.0      NaN        NaN
# Tetra Pack            NaN         NaN      NaN     NaN      NaN        NaN
#
# Product Name        Lassi    Milk  Paneer  Yogurt
# Storage Condition
# Ambient               NaN     NaN     NaN     NaN
# Frozen                NaN     NaN     NaN  5224.0
# Polythene Packet      NaN   331.0     NaN     NaN
# Refrigerated       6637.0     NaN  4702.0  5927.0
# Tetra Pack            NaN  5213.0     NaN     NaN

# %%
sns.barplot(x=df["Sales Channel"],y=df["Quantity in Stock (liters/kg)"],hue=df["Brand"])
# Out:
# <AxesSubplot: xlabel='Sales Channel', ylabel='Quantity in Stock (liters/kg)'>

# %%
sns.swarmplot(y=df["Approx. Total Revenue(INR)"],x=df["Customer Location"],hue=df["Brand"])
plt.xticks(rotation=90)
# Out:
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 68.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 67.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 67.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.boxplot(x=df["Product Name"],y=df["Approx. Total Revenue(INR)"],hue=df["Storage Condition"])
# Out:
# <AxesSubplot: xlabel='Product Name', ylabel='Approx. Total Revenue(INR)'>

# %%
sns.violinplot(x=df["Product Name"],y=df["Price per Unit (sold)"],hue=df["Sales Channel"])
# Out:
# <AxesSubplot: xlabel='Product Name', ylabel='Price per Unit (sold)'>

# %%
sns.distplot(x=df["Approx. Total Revenue(INR)"])
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_18192\2434746246.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["Approx. Total Revenue(INR)"])
# <AxesSubplot: ylabel='Density'>

# %%
sns.relplot(y=df["Quantity in Stock (liters/kg)"],x=df["Total Land Area (acres)"],hue=df["Farm Size"],kind="line")

# %%
sns.relplot(y=df["Quantity in Stock (liters/kg)"],x=df["Total Land Area (acres)"],hue=df["Brand"],kind="line")

# %%
pd.crosstab(df["Brand"],df["Product Name"])
# Out:
# Product Name          Butter  Buttermilk  Cheese  Curd  Ghee  Ice Cream  \
# Brand
# Amul                     108          89     111   121    95        106
# Britannia Industries       0           0      88     0     0          0
# Dodla Dairy                0           0       0     0     0        105
# Dynamix Dairies            0           0     106     0     0          0
# Mother Dairy             117         118       0   119   104        112
# Palle2patnam               0           0       0     0     0        100
# Parag Milk Foods         102           0       0     0     0          0
# Passion Cheese             0           0      96     0     0          0
# Raj                        0         112       0   119   104          0
# Sudha                      0         116       0   120    99          0
# Warana                   104           0       0     0     0          0
#
# Product Name          Lassi  Milk  Paneer  Yogurt
# Brand
# ...

# %%
sns.relplot(y=df["Price per Unit"],x=df["Quantity (liters/kg)"],hue=df["Product Name"],kind="line")

# %%
sns.scatterplot(x=df["Number of Cows"],y=df["Total Land Area (acres)"],hue=df["Brand"])
# Out:
# <AxesSubplot: xlabel='Number of Cows', ylabel='Total Land Area (acres)'>

# %%
sns.swarmplot(y=df["Total Value"],x=df["Brand"],hue=df["Storage Condition"])
# Out:
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 40.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 79.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df
# Out:
#            Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0         Telangana                   310.84              96    Medium
# 1     Uttar Pradesh                    19.19              44     Large
# 2        Tamil Nadu                   581.69              24    Medium
# 3         Telangana                   908.00              89     Small
# 4       Maharashtra                   861.95              21    Medium
# ...             ...                      ...             ...       ...
# 4320          Delhi                   748.71              89    Medium
# 4321      Jharkhand                   385.91              29     Large
# 4322     Chandigarh                   311.54              65     Small
# 4323    Maharashtra                   890.55              90     Small
# 4324      Rajasthan                   492.86              58     Large
#
#             Date  Product ID Product Name                 Brand  \
# ...

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Storage Condition', 'Production Date', 'Expiration Date',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %%
df=pd.read_csv("./dairy_dataset.csv")
