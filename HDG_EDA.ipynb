# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df.Continent.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot: ylabel='Continent'>

# %%
df["Human Development Groups"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
sns.stripplot(x=df["Continent"],y=df["Gross National Income Per Capita (2021)"],color="blue")

sns.stripplot(x=df["Continent"],y=df["Gross National Income Per Capita (2002)"],color="orange")
# Out:
# <AxesSubplot: xlabel='Continent', ylabel='Gross National Income Per Capita (2021)'>

# %%
sns.jointplot(x=df["Gross National Income Per Capita (2002)"],y=df["Gross National Income Per Capita (2021)"],kind="kde")

# %%
sns.violinplot(x=df["Human Development Groups"],y=df["Gross National Income Per Capita (2021)"],hue=df["Hemisphere"])
# Out:
# <AxesSubplot: xlabel='Human Development Groups', ylabel='Gross National Income Per Capita (2021)'>

# %%
sns.relplot(x=df["Gross National Income Per Capita (2002)"],y=df["Gross National Income Per Capita (2021)"],hue=df["Human Development Groups"],kind='line')

# %%
for i in df.iloc[:,7:]:
    df[i].fillna(df[i].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# ISO3                                        0
# Country                                     0
# Continent                                   0
# Hemisphere                                  0
# Human Development Groups                    4
# UNDP Developing Regions                    44
# HDI Rank (2021)                             4
# Gross National Income Per Capita (1990)     0
# Gross National Income Per Capita (1991)     0
# Gross National Income Per Capita (1992)     0
# Gross National Income Per Capita (1993)     0
# Gross National Income Per Capita (1994)     0
# Gross National Income Per Capita (1995)     0
# Gross National Income Per Capita (1996)     0
# Gross National Income Per Capita (1997)     0
# Gross National Income Per Capita (1998)     0
# Gross National Income Per Capita (1999)     0
# Gross National Income Per Capita (2000)     0
# Gross National Income Per Capita (2001)     0
# Gross National Income Per Capita (2002)     0
# ...

# %%
sns.distplot(df["Gross National Income Per Capita (2021)"])
sns.distplot(df["Gross National Income Per Capita (2002)"])
plt.xlabel("GNIP 2002 2021")
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_23668\1220202605.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Gross National Income Per Capita (2021)"])
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_23668\1220202605.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df.groupby("Continent").sum().sort_values("Gross National Income Per Capita (2021)")grou.tail(15).plot()
plt.legend(loc=(0,1))
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_23668\3634478592.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Continent").sum().sort_values("Gross National Income Per Capita (2021)").tail(15).plot()

# %%
df.groupby("Country").sum().sort_values("HDI Rank (2021)")["HDI Rank (2021)"].reset_index()
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_23668\834318854.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Country").sum().sort_values("HDI Rank (2021)")["HDI Rank (2021)"].reset_index()
#                       Country  HDI Rank (2021)
# 0                     Somalia              0.0
# 1                 North Korea              0.0
# 2                      Monaco              0.0
# 3                       Nauru              0.0
# 4                 Switzerland              1.0
# ..                        ...              ...
# 190                   Burundi            187.0
# 191  Central African Republic            188.0
# 192                     Niger            189.0
# 193                      Chad            190.0
# 194               South Sudan            191.0
#
# ...

# %%
df["Hemisphere"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot: ylabel='Hemisphere'>

# %%
sns.barplot(y=df["Gross National Income Per Capita (2021)"],x=df["Human Development Groups"],hue=df["Hemisphere"])
# Out:
# <AxesSubplot: xlabel='Human Development Groups', ylabel='Gross National Income Per Capita (2021)'>

# %%
sns.scatterplot(x=df["Gross National Income Per Capita (1990)"],y=df["Gross National Income Per Capita (2021)"],hue=df["Human Development Groups"])
# Out:
# <AxesSubplot: xlabel='Gross National Income Per Capita (1990)', ylabel='Gross National Income Per Capita (2021)'>

# %%
df.groupby("Country").sum().sort_values("Gross National Income Per Capita (2021)").tail(15).plot()
plt.legend(loc=(0,1))
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_23668\3119430855.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Country").sum().sort_values("Gross National Income Per Capita (2021)").tail(15).plot()

# %%
df.isna().sum()
# Out:
# ISO3                                        0
# Country                                     0
# Continent                                   0
# Hemisphere                                  0
# Human Development Groups                    4
# UNDP Developing Regions                    44
# HDI Rank (2021)                             4
# Gross National Income Per Capita (1990)     0
# Gross National Income Per Capita (1991)     0
# Gross National Income Per Capita (1992)     0
# Gross National Income Per Capita (1993)     0
# Gross National Income Per Capita (1994)     0
# Gross National Income Per Capita (1995)     0
# Gross National Income Per Capita (1996)     0
# Gross National Income Per Capita (1997)     0
# Gross National Income Per Capita (1998)     0
# Gross National Income Per Capita (1999)     0
# Gross National Income Per Capita (2000)     0
# Gross National Income Per Capita (2001)     0
# Gross National Income Per Capita (2002)     0
# ...

# %%
y=df["Human Development Groups"]
from sklearn.model_selection import train_test_split
x=df.iloc[:,9:32]
xtr,xts,ytr,yts=train_test_split(x,y,random_state=92,test_size=0.3)

# %%
sns.swarmplot(y=df["Gross National Income Per Capita (2021)"],x=df["Continent"])

# %%
sns.swarmplot(y=df["Gross National Income Per Capita (2021)"],x=df["Continent"])
# Out:
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Continent', ylabel='Gross National Income Per Capita (2021)'>
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 18.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.isna().sum()
# Out:
# ISO3                                        0
# Country                                     0
# Continent                                   0
# Hemisphere                                  0
# Human Development Groups                    4
# UNDP Developing Regions                    44
# HDI Rank (2021)                             4
# Gross National Income Per Capita (1990)     0
# Gross National Income Per Capita (1991)     0
# Gross National Income Per Capita (1992)     0
# Gross National Income Per Capita (1993)     0
# Gross National Income Per Capita (1994)     0
# Gross National Income Per Capita (1995)     0
# Gross National Income Per Capita (1996)     0
# Gross National Income Per Capita (1997)     0
# Gross National Income Per Capita (1998)     0
# Gross National Income Per Capita (1999)     0
# Gross National Income Per Capita (2000)     0
# Gross National Income Per Capita (2001)     0
# Gross National Income Per Capita (2002)     0
# ...

# %%
df.isna().sum()
# Out:
# ISO3                                       0
# Country                                    0
# Continent                                  0
# Hemisphere                                 0
# Human Development Groups                   0
# UNDP Developing Regions                    0
# HDI Rank (2021)                            0
# Gross National Income Per Capita (1990)    0
# Gross National Income Per Capita (1991)    0
# Gross National Income Per Capita (1992)    0
# Gross National Income Per Capita (1993)    0
# Gross National Income Per Capita (1994)    0
# Gross National Income Per Capita (1995)    0
# Gross National Income Per Capita (1996)    0
# Gross National Income Per Capita (1997)    0
# Gross National Income Per Capita (1998)    0
# Gross National Income Per Capita (1999)    0
# Gross National Income Per Capita (2000)    0
# Gross National Income Per Capita (2001)    0
# Gross National Income Per Capita (2002)    0
# Gross National Income Per Capita (2003)    0
# ...

# %%
df.dropna(inplace=True)

# %%
df.iloc[:,9:].fillna(0,inplace=True)

# %%
df.dropna(inplace=True)

# %%
for i in df.iloc[:,9:]:
    df[i].fillna(0)

# %%
df.isna().sum()
# Out:
# ISO3                                        0
# Country                                     0
# Continent                                   0
# Hemisphere                                  0
# Human Development Groups                    4
# UNDP Developing Regions                    44
# HDI Rank (2021)                             4
# Gross National Income Per Capita (1990)     0
# Gross National Income Per Capita (1991)     0
# Gross National Income Per Capita (1992)     0
# Gross National Income Per Capita (1993)     0
# Gross National Income Per Capita (1994)     0
# Gross National Income Per Capita (1995)     0
# Gross National Income Per Capita (1996)     0
# Gross National Income Per Capita (1997)     0
# Gross National Income Per Capita (1998)     0
# Gross National Income Per Capita (1999)     0
# Gross National Income Per Capita (2000)     0
# Gross National Income Per Capita (2001)     0
# Gross National Income Per Capita (2002)     0
# ...

# %%
df=pd.read_csv("./Gross National Income Per Capita.csv")
df
# Out:
#     ISO3               Country Continent           Hemisphere  \
# 0    AFG           Afghanistan      Asia  Northern Hemisphere
# 1    AGO                Angola    Africa  Southern Hemisphere
# 2    ALB               Albania    Europe  Northern Hemisphere
# 3    AND               Andorra    Europe  Northern Hemisphere
# 4    ARE  United Arab Emirates      Asia  Northern Hemisphere
# ..   ...                   ...       ...                  ...
# 190  WSM                 Samoa   Oceania  Southern Hemisphere
# 191  YEM                 Yemen      Asia  Northern Hemisphere
# 192  ZAF          South Africa    Africa  Southern Hemisphere
# 193  ZMB                Zambia    Africa  Southern Hemisphere
# 194  ZWE              Zimbabwe    Africa  Southern Hemisphere
#
#     Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                        Low                      SA            180.0
# 1                     Medium                     SSA            148.0
# ...
